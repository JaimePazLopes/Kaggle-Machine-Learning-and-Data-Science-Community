# %% [markdown]
# **[Data Visualization Home Page](https://www.kaggle.com/learn/data-visualization)**
#
# ---

# %% [markdown]
# Now it's time for you to demonstrate your new skills with a project of your own!
#
# In this exercise, you will work with a dataset of your choosing.  Once you've selected a dataset, you'll design and create your own plot to tell interesting stories behind the data!
#
# ## Setup
#
# Run the next cell to import and configure the Python libraries that you need to complete the exercise.

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# The questions below will give you feedback on your work. Run the following cell to set up the feedback system.

# %%
# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex7 import *
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# ## Step 1: Attach a dataset to the notebook
#
# Begin by selecting a CSV dataset from [Kaggle Datasets](https://www.kaggle.com/datasets).  If you're unsure how to do this or would like to work with your own data, please revisit the instructions in the previous tutorial.
#
# Once you have selected a dataset, click on the **[+ Add Data]** option in the top right corner.  This will generate a pop-up window that you can use to search for your chosen dataset.
#
# ![ex6_search_dataset](https://i.imgur.com/cIIWPUS.png)
#
# Once you have found the dataset, click on the **[Add]** button to attach it to the notebook.  You can check that it was successful by looking at the **Data** dropdown menu to the right of the notebook -- look for an **input** folder containing a subfolder that matches the name of the dataset.
#
# ![ex6_dataset_added](https://i.imgur.com/XOCpdak.png)
#
# You can click on the carat to the right of the name of the dataset to double-check that it contains a CSV file.  For instance, the image below shows that the example dataset contains two CSV files: (1) **dc-wikia-data.csv**, and (2) **marvel-wikia-data.csv**.
#
# ![ex6_dataset_dropdown](https://i.imgur.com/UZOsR6S.png)
#
# Once you've uploaded a dataset with a CSV file, run the code cell below **without changes** to receive credit for your work!

# %%
# Check for a dataset with a CSV file
step_1.check()
# Out:
# Correct:

# %% [markdown]
# ## Step 2: Specify the filepath
#
# Now that the dataset is attached to the notebook, you can find its filepath.  To do this, use the **Workspace** menu to list the set of files, and click on the CSV file you'd like to use.  This will open the CSV file in a tab below the notebook.  You can find the filepath towards the top of this new tab.
#
# ![ex6_filepath](https://i.imgur.com/EssGpuJ.png)
#
# After you find the filepath corresponding to your dataset, fill it in as the value for `my_filepath` in the code cell below, and run the code cell to check that you've provided a valid filepath.  For instance, in the case of this example dataset, we would set
# ```
# my_filepath = "../input/fivethirtyeight-comic-characters-dataset/dc-wikia-data.csv"
# ```
# Note that **you must enclose the filepath in quotation marks**; otherwise, the code will return an error.
#
# Once you've entered the filepath, you can close the tab below the notebook by clicking on the **[X]** at the top of the tab.

# %%
# Fill in the line below: Specify the path of the CSV file to read
my_filepath = "../input/fivethirtyeight-comic-characters-dataset/marvel-wikia-data.csv"

# Check for a valid filepath to a CSV file in a dataset
step_2.check()
# Out:
# Correct:

# %% [markdown]
# ## Step 3: Load the data
#
# Use the next code cell to load your data file into `my_data`.  Use the filepath that you specified in the previous step.

# %%
# Fill in the line below: Read the file into a variable my_data
my_data = pd.read_csv(my_filepath)

# Check that a dataset has been uploaded into my_data
step_3.check()
# Out:
# Correct:

# %% [markdown]
# **_After the code cell above is marked correct_**, run the code cell below without changes to view the first five rows of the data.

# %%
# Print the first five rows of the data
my_data.head()
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3     Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4     Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
#
#                ALIVE  APPEARANCES FIRST APPEARANCE    Year
# 0  Living Characters       4043.0           Aug-62  1962.0
# 1  Living Characters       3360.0           Mar-41  1941.0
# 2  Living Characters       3061.0           Oct-74  1974.0
# 3  Living Characters       2961.0           Mar-63  1963.0
# 4  Living Characters       2258.0           Nov-50  1950.0

# %%
my_data.isnull().sum()
# Out:
# page_id                 0
# name                    0
# urlslug                 0
# ID                   3770
# ALIGN                2812
# EYE                  9767
# HAIR                 4264
# SEX                   854
# GSM                 16286
# ALIVE                   3
# APPEARANCES          1096
# FIRST APPEARANCE      815
# Year                  815
# dtype: int64

# %% [markdown]
# ## Step 4: Visualize the data
#
# Use the next code cell to create a figure that tells a story behind your dataset.  You can use any chart type (_line chart, bar chart, heatmap, etc_) of your choosing!

# %%
my_data[(my_data["SEX"]!="Male Characters")&(my_data["SEX"]!="Female Characters")&~(pd.isnull(my_data["SEX"]))]
# Out:
#        page_id                                              name  \
# 61        2042                        Loki Laufeyson (Earth-616)
# 106      18186                      Venom (Symbiote) (Earth-616)
# 630      57175                    Carnage (Symbiote) (Earth-616)
# 690       1292                      Captain Universe (Earth-616)
# 1154     23853                                 Xavin (Earth-616)
# 1160      7995                          Living Brain (Earth-616)
# 1364    607100                         Emily Preston (Earth-616)
# 1499    442178                      Toxin (Symbiote) (Earth-616)
# 1563    573762                            H.E.L.E.N. (Earth-616)
# 1609     37431    Centrally Located Organic Computer (Earth-616)
# 1615    670753               Venom (Symbiote) (Mania) (Earh-616)
# 1930    499801                 Anti-Venom (Symbiote) (Earth-616)
# 2496    512834                      Agony (Symbiote) (Earth-616)
# 2497    512836                     Lasher (Symbiote) (Earth-616)
# 2499    512831                      Phage (Symbiote) (Earth-616)
# 2500    512832                       Riot (Symbiote) (Earth-616)
# 2548    605379                          Recorder 451 (Earth-616)
# 6975                       \/Vladimir_(Bomb)_(Earth-616)
# 7709                            \/KhL%CE%98G_(Earth-616)
# 8361                       \/Gungnir_(Robot)_(Earth-616)
# 8624                      \/Artificial_being_(Earth-616)
# 8676   \/Robert_Bruce_Banner_(Mandarin_Robot)_(Earth-...
# 11907                       \/Mecho-Assassin_(Earth-616)
# 11996                             \/Changers_(Earth-616)
# 13459                            \/Soul_Slug_(Earth-616)
# 13767          \/Iron_Man_(Taskmaster_Robot)_(Earth-616)
# 13804            \/Vision_(Taskmaster_Robot)_(Earth-616)
# 14546                       \/Tony_Stark_2.0_(Earth-616)
# 15061                    \/Deathwalker_Prime_(Earth-616)
# 15175              \/Blockers_Bots_(Hazards)_(Earth-616)
# 15246                    \/Sappers_(Hazards)_(Earth-616)
# 15247                  \/Scorchers_(Hazards)_(Earth-616)
# 15385                     \/Walking_Stiletto_(Earth-616)
# 15493                               \/Warbot_(Earth-616)
# 15804                             \/Batch-13_(Earth-616)
#
#                                   ID               ALIGN            EYE  \
# 61                  No Dual Identity  Neutral Characters     Green Eyes
# 106    Known to Authorities Identity  Neutral Characters  Variable Eyes
# 630                  Public Identity      Bad Characters     White Eyes
# 690                  Secret Identity     Good Characters  Variable Eyes
# 1154                 Secret Identity     Good Characters     Brown Eyes
# 1160                             NaN  Neutral Characters    Yellow Eyes
# 1364                No Dual Identity     Good Characters     Brown Eyes
# 1499                             NaN  Neutral Characters  Variable Eyes
# 1563                No Dual Identity     Good Characters            NaN
# 1609                             NaN     Good Characters            NaN
# 1615                             NaN  Neutral Characters  Variable Eyes
# 1930                             NaN     Good Characters       Red Eyes
# 2496                             NaN  Neutral Characters     White Eyes
# 2497                 Secret Identity  Neutral Characters     White Eyes
# 2499                             NaN  Neutral Characters     White Eyes
# 2500                             NaN  Neutral Characters     White Eyes
# 2548                 Public Identity      Bad Characters       Red Eyes
# 2963                             NaN                 NaN            NaN
# 3101                 Secret Identity  Neutral Characters      Blue Eyes
# 3125                             NaN                 NaN    Yellow Eyes
# 3263                 Secret Identity  Neutral Characters     White Eyes
# 3337                 Public Identity     Good Characters            NaN
# 3340                 Public Identity      Bad Characters            NaN
# 3630                             NaN     Good Characters     White Eyes
# 4982                             NaN     Good Characters     Green Eyes
# 5027                No Dual Identity      Bad Characters     White Eyes
# 6551                 Public Identity  Neutral Characters     White Eyes
# 6905                No Dual Identity  Neutral Characters    Yellow Eyes
# 6953                No Dual Identity     Good Characters            NaN
# 6975                No Dual Identity  Neutral Characters    Purple Eyes
# 7709                             NaN      Bad Characters  Variable Eyes
# 8361                No Dual Identity      Bad Characters            NaN
# 8624                             NaN      Bad Characters            NaN
# 8676                 Secret Identity      Bad Characters     Green Eyes
# 11907                Secret Identity      Bad Characters     Black Eyes
# 11996                Secret Identity      Bad Characters            NaN
# 13459                Secret Identity      Bad Characters     Black Eyes
# 13767                Secret Identity      Bad Characters            NaN
# 13804                Secret Identity      Bad Characters            NaN
# 14546                Secret Identity     Good Characters    Yellow Eyes
# 6               \/Reed_Richards_(Earth-616)   Public Identity
# 7              \/Hulk_(Robert_Bruce_Banner)   Public Identity
# 8               \/Scott_Summers_(Earth-616)   Public Identity
# 9              \/Jonathan_Storm_(Earth-616)   Public Identity
# 10                \/Henry_McCoy_(Earth-616)   Public Identity
# 11                \/Susan_Storm_(Earth-616)   Public Identity
# 12             \/Namor_McKenzie_(Earth-616)  No Dual Identity
# 13               \/Ororo_Munroe_(Earth-616)   Public Identity
# 14             \/Clinton_Barton_(Earth-616)   Public Identity
#
#                  ALIGN         EYE        HAIR                SEX  GSM  \
# 0      Good Characters  Hazel Eyes  Brown Hair    Male Characters  NaN
# 1      Good Characters   Blue Eyes  White Hair    Male Characters  NaN
# 2   Neutral Characters   Blue Eyes  Black Hair    Male Characters  NaN
# 3      Good Characters   Blue Eyes  Black Hair    Male Characters  NaN
# 4      Good Characters   Blue Eyes  Blond Hair    Male Characters  NaN
# 5      Good Characters   Blue Eyes     No Hair    Male Characters  NaN
# 6      Good Characters  Brown Eyes  Brown Hair    Male Characters  NaN
# 7      Good Characters  Brown Eyes  Brown Hair    Male Characters  NaN
# 8   Neutral Characters  Brown Eyes  Brown Hair    Male Characters  NaN
# 9      Good Characters   Blue Eyes  Blond Hair    Male Characters  NaN
# 10     Good Characters   Blue Eyes   Blue Hair    Male Characters  NaN
# 11     Good Characters   Blue Eyes  Blond Hair  Female Characters  NaN
# 12  Neutral Characters  Green Eyes  Black Hair    Male Characters  NaN
# 13     Good Characters   Blue Eyes  White Hair  Female Characters  NaN
# 14     Good Characters   Blue Eyes  Blond Hair    Male Characters  NaN
#
#                 ALIVE  APPEARANCES FIRST APPEARANCE    Year
# 0   Living Characters       4043.0           Aug-62  1962.0
# 1   Living Characters       3360.0           Mar-41  1941.0
# 2   Living Characters       3061.0           Oct-74  1974.0
# 3   Living Characters       2961.0           Mar-63  1963.0
# 4   Living Characters       2258.0           Nov-50  1950.0
# 5   Living Characters       2255.0           Nov-61  1961.0
# 6   Living Characters       2072.0           Nov-61  1961.0
# 7   Living Characters       2017.0           May-62  1962.0
# 8   Living Characters       1955.0           Sep-63  1963.0
# 9   Living Characters       1934.0           Nov-61  1961.0
# 10  Living Characters       1825.0           Sep-63  1963.0
# 11  Living Characters       1713.0           Nov-61  1961.0
# 12  Living Characters       1528.0              NaN     NaN
# 13  Living Characters       1512.0           May-75  1975.0
# 14  Living Characters       1394.0           Sep-64  1964.0

# %%
year = app[~pd.isnull(app["Year"])]
year = year[year["APPEARANCES"]>500]
year.sort_values("Year")
# Out:
#     page_id                               name  \
# 60     1836  Human Torch (Android) (Earth-616)
# 1      7139    Captain America (Steven Rogers)
# 51    15823  James Buchanan Barnes (Earth-616)
# 59     1811        Patricia Walker (Earth-616)
# 61     2042         Loki Laufeyson (Earth-616)
# ..      ...                                ...
# 32     2527        Katherine Pryde (Earth-616)
# 35     3765             Emma Frost (Earth-616)
# 50     1276         Samuel Guthrie (Earth-616)
# 54    32498         Nathan Summers (Earth-616)
# 52     1680            Remy LeBeau (Earth-616)
#
#                                 urlslug                ID               ALIGN  \
# 60  \/Human_Torch_(Android)_(Earth-616)   Public Identity     Good Characters
# 1     \/Captain_America_(Steven_Rogers)   Public Identity     Good Characters
# 51  \/James_Buchanan_Barnes_(Earth-616)   Secret Identity     Good Characters
# 59        \/Patricia_Walker_(Earth-616)   Secret Identity     Good Characters
# 61         \/Loki_Laufeyson_(Earth-616)  No Dual Identity  Neutral Characters
# ..                                  ...               ...                 ...
# 32        \/Katherine_Pryde_(Earth-616)   Secret Identity     Good Characters
# 35             \/Emma_Frost_(Earth-616)   Public Identity  Neutral Characters
# 50         \/Samuel_Guthrie_(Earth-616)   Secret Identity     Good Characters
# 54         \/Nathan_Summers_(Earth-616)   Public Identity  Neutral Characters
# 52            \/Remy_LeBeau_(Earth-616)   Secret Identity     Good Characters
#
#                EYE        HAIR                     SEX                  GSM  \
# 60       Blue Eyes  Blond Hair         Male Characters                  NaN
# 1        Blue Eyes  White Hair         Male Characters                  NaN
# 51      Brown Eyes  Brown Hair         Male Characters                  NaN
# 59       Blue Eyes    Red Hair       Female Characters                  NaN
# 61      Green Eyes  Black Hair  Genderfluid Characters  Bisexual Characters
# ..             ...         ...                     ...                  ...
# 32      Hazel Eyes  Brown Hair       Female Characters                  NaN
# 35       Blue Eyes  Brown Hair       Female Characters                  NaN
# 50       Blue Eyes  Blond Hair         Male Characters                  NaN
# 54       Blue Eyes  White Hair         Male Characters                  NaN
# 52  Black Eyeballs  Brown Hair         Male Characters                  NaN
#
#                 ALIVE  APPEARANCES FIRST APPEARANCE    Year
# 60  Living Characters        548.0           Oct-39  1939.0
# 1   Living Characters       3360.0           Mar-41  1941.0
# 51  Living Characters        641.0           Mar-41  1941.0
# 59  Living Characters        550.0           Nov-44  1944.0
# 61  Living Characters        532.0           Aug-49  1949.0
# ..                ...          ...              ...     ...
# 32  Living Characters        886.0           Jan-80  1980.0
# 35  Living Characters        880.0           Jan-80  1980.0
# 50  Living Characters        657.0           Nov-82  1982.0
# 54  Living Characters        612.0           Jan-86  1986.0
# 52  Living Characters        636.0           Jul-90  1990.0
#
# [69 rows x 13 columns]

# %%
plt.figure(figsize=(6,20))
sns.countplot(y=my_data["Year"])

# %%
sns.countplot(x=my_data["ALIVE"], hue=my_data["SEX"])

# %%
sns.countplot(y=my_data["SEX"])

# %%
sns.countplot(y=my_data["HAIR"], order = my_data['HAIR'].value_counts().index)

# %%
sns.countplot(x=my_data["ALIGN"], hue=my_data["SEX"])

# %%
# Create a plot
sns.countplot(x=my_data["ID"])

# Check that a figure appears below
step_4.check()
# Out:
# Correct:

# %% [markdown]
# ## Keep going
#
# Learn how to use your skills after completing the micro-course to create data visualizations in a **[final tutorial](https://www.kaggle.com/alexisbcook/creating-your-own-notebooks)**.

# %% [markdown]
# ---
# **[Data Visualization Home Page](https://www.kaggle.com/learn/data-visualization)**
#
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum) to chat with other Learners.*
